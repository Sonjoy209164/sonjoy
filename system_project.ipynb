# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonjoy209164/sonjoy/blob/main/system_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Streamlit initialize

# %%
# !pip install -q streamlit
# !pip install unicode
! pip install unidecode
# !pip install tensorflow
# !pip install keras
# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-gpu
# !pip install xlrd==1.2.0
# !pip install openpyxl
# !pip install bangla-stemmer
# !sudo apt install tesseract-ocr
# !apt-get install -y poppler-utils
# !pip install pytesseract
#install The pytesseract library using the command
# !sudo apt install tesseract-ocr
# !sudo apt install tesseract-ocr-ben
# !pip install pdf2image
# !mkdir photos/
# !mkdir Text
# !touch input.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 34.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 100.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.1 MB/s eta 0:00:00
# Collecting unicode
#   Downloading unicode-2.9-py2.py3-none-any.whl (14 kB)
# Installing collected packages: unicode
# Successfully installed unicode-2.9
# Collecting unidecode
#   Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.7
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 101.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 49.2 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed keras-2.15.0 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-estimator-2.15.0
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting xlrd==1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
# Successfully installed xlrd-1.2.0
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Collecting bangla-stemmer
#   Downloading bangla_stemmer-1.0-py3-none-any.whl (9.1 kB)
# Installing collected packages: bangla-stemmer
# Successfully installed bangla-stemmer-1.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 10 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 2s (2,999 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 120880 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 10 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.2 [186 kB]
# Fetched 186 kB in 1s (240 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 120927 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.2_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-ben
# 0 upgraded, 1 newly installed, 0 to remove and 10 not upgraded.
# Need to get 516 kB of archives.
# After this operation, 870 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-ben all 1:4.00~git30-7274cfa-1.1 [516 kB]
# Fetched 516 kB in 1s (539 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-ben.
# (Reading database ... 120957 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-ben_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-ben (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-ben (1:4.00~git30-7274cfa-1.1) ...
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (9.4.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3

# %%
# %%writefile app.py
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)
st.write ("sonjoy")

import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
!npm install localtunnel
!streamlit run /content/app.py &>/content/logs.txt &
!npx localtunnel --port 8501
#35.196.193.95
# Out:
# Writing app.py

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings('ignore')

import os
import io
from pandas import read_excel
import re
from re import sub
import multiprocessing
from unidecode import unidecode
from time import time
from collections import Counter

from sklearn import metrics
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Activation, Embedding, Flatten, Bidirectional, MaxPooling2D, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical



import h5py
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score


from nltk.corpus import stopwords
import nltk
import re
from nltk.stem import WordNetLemmatizer
import string
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import pytesseract
import shutil
import os
from PIL import Image
import os
import cv2
import matplotlib.pyplot as plt

import pytesseract
# %matplotlib inline

import pytesseract
from PIL import ImageEnhance, ImageFilter, Image

# #installing poppler
# !apt-get install -y poppler-utils
#import module
from pdf2image import convert_from_path

# %% [markdown]
# # pdf to image conversion code

# %%
#store pdf with convert_from_path function
#import module

# Import module
from pdf2image import convert_from_path

# Define the path to the PDF file
pdf_file = '/content/uploaded_file.pdf'

# Convert PDF to a list of images
images = convert_from_path(pdf_file)

# Save each page as a PNG in /content/photos directory
for i, image in enumerate(images):
    image.save(f'/content/photos/page_{i + 1}.png', 'PNG')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588         if "Pages" not in d:
# --> 589             raise ValueError
#     590
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-6-f97d6394b10d> in <cell line: 11>()
#       9
#      10 # Convert PDF to a list of images
# ---> 11 images = convert_from_path(pdf_file)
#      12
#      13 # Save each page as a PNG in /content/photos directory
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     125         poppler_path = poppler_path.as_posix()
#     126
# --> 127     page_count = pdfinfo_from_path(
#     128         pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129     )["Pages"]
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     596         )
#     597     except ValueError:
# --> 598         raise PDFPageCountError(
#     599             f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     600         )
#
# PDFPageCountError: Unable to get page count.
# I/O Error: Couldn't open file '/content/7march.pdf': No such file or directory.

# %% [markdown]
# # Extracting text and saving it in a dataframe NAMED DF

# %%
# # import pytesseract
# # import shutil
# # import os
# # from PIL import Image
# # import pandas as pd

# image_folder_path = '/content/photos'
# output_text_path = '/content/Text'

# if not os.path.exists(output_text_path):
#     os.makedirs(output_text_path)

# image_files = os.listdir(image_folder_path)

# # Create an empty dataframe
# df_test = pd.DataFrame(columns=['Extracted Text'])

# for image_file in image_files:
#     image_path = os.path.join(image_folder_path, image_file)

#     img = Image.open(image_path)

#     extracted_text = pytesseract.image_to_string(img, lang='eng+ben')

#     text_output_path = os.path.join(output_text_path, os.path.splitext(image_file)[0] + ".txt")

#     with open(text_output_path, 'w') as text_file:
#         text_file.write(extracted_text)

#     # Add the file name and extracted text to the dataframe
#     df_test = df_test.append({ 'Extracted Text': extracted_text}, ignore_index=True)

# # Now you have a dataframe 'df' containing the file names and extracted text

# %%
# pdf_file = '/content/নারদ ভক্তি সূত্রঃ.pdf'

# # Convert PDF to a list of images
# images = convert_from_path(pdf_file)

# # Create an empty dataframe
# df_test = pd.DataFrame(columns=['Page Number', 'Extracted Text'])

# # Iterate through each page and extract text
# for i, image in enumerate(images):
#     # Convert PIL Image to bytes
#     img_byte_array = io.BytesIO()
#     image.save(img_byte_array, format='PNG')
#     img_byte_array = img_byte_array.getvalue()

#     # Use Tesseract OCR on the image
#     extracted_text = pytesseract.image_to_string(Image.open(io.BytesIO(img_byte_array)), lang='eng+ben')

#     # Add page number and extracted text to the dataframe
#     df_test = df_test.append({'Page Number': i + 1, 'Extracted Text': extracted_text}, ignore_index=True)

# # Display the dataframe
# print(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588         if "Pages" not in d:
# --> 589             raise ValueError
#     590
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-7-dfc6436572b0> in <cell line: 4>()
#       2
#       3 # Convert PDF to a list of images
# ----> 4 images = convert_from_path(pdf_file)
#       5
#       6 # Create an empty dataframe
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     125         poppler_path = poppler_path.as_posix()
#     126
# --> 127     page_count = pdfinfo_from_path(
#     128         pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129     )["Pages"]
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     596         )
#     597     except ValueError:
# --> 598         raise PDFPageCountError(
#     599             f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     600         )
#
# PDFPageCountError: Unable to get page count.
# I/O Error: Couldn't open file '/content/<e0><a6><a8><e0><a6><be><e0><a6><b0><e0><a6><a6> <e0><a6><ad><e0><a6><95><e0><a7><8d><e0><a6><a4><e0><a6><bf> <e0><a6><b8><e0><a7><82><e0><a6><a4><e0><a7><8d><e0><a6><b0><e0><a6><83>.pdf': No such file or directory.

# %%
import pytesseract
import pandas as pd
from pdf2image import convert_from_path
from PIL import Image
import io
import concurrent.futures

def process_page(page_number, image):
    # Convert PIL Image to bytes
    img_byte_array = io.BytesIO()
    image.save(img_byte_array, format='PNG')
    img_byte_array = img_byte_array.getvalue()

    # Use Tesseract OCR on the image
    extracted_text = pytesseract.image_to_string(Image.open(io.BytesIO(img_byte_array)), lang='eng+ben')

    return {'Page Number': page_number, 'Extracted Text': extracted_text}

# Define the path to the PDF file
pdf_file = '/content/uploaded_file.pdf'

# Convert PDF to a list of images
images = convert_from_path(pdf_file)

# Create an empty dataframe
df_test = pd.DataFrame(columns=['Page Number', 'Extracted Text'])

# Process pages in parallel
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = [executor.submit(process_page, i + 1, image) for i, image in enumerate(images)]

    # Collect results
    for future in concurrent.futures.as_completed(results):
        df_test = df_test.append(future.result(), ignore_index=True)

# Display the dataframe
print(df_test)
#1.47s
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588         if "Pages" not in d:
# --> 589             raise ValueError
#     590
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-8-6596ec9a0394> in <cell line: 23>()
#      21
#      22 # Convert PDF to a list of images
# ---> 23 images = convert_from_path(pdf_file)
#      24
#      25 # Create an empty dataframe
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     125         poppler_path = poppler_path.as_posix()
#     126
# --> 127     page_count = pdfinfo_from_path(
#     128         pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129     )["Pages"]
#
# /usr/local/lib/python3.10/dist-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     596         )
#     597     except ValueError:
# --> 598         raise PDFPageCountError(
#     599             f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     600         )
#
# PDFPageCountError: Unable to get page count.
# I/O Error: Couldn't open file '/content/<e0><a6><a8><e0><a6><be><e0><a6><b0><e0><a6><a6> <e0><a6><ad><e0><a6><95><e0><a7><8d><e0><a6><a4><e0><a6><bf> <e0><a6><b8><e0><a7><82><e0><a6><a4><e0><a7><8d><e0><a6><b0><e0><a6><83>.pdf': No such file or directory.

# %%
# import pytesseract
# import pandas as pd
# from pdf2image import convert_from_path
# from PIL import Image
# import io
# import concurrent.futures

# def process_page(page_number, image):
#     img_byte_array = io.BytesIO()
#     image.save(img_byte_array, format='PNG')
#     img_byte_array = img_byte_array.getvalue()

#     # Use Tesseract OCR to get word-level information
#     data = pytesseract.image_to_data(Image.open(io.BytesIO(img_byte_array)), lang='eng+ben', output_type=pytesseract.Output.DICT)

#     # Extract text from non-empty word blocks
#     extracted_text = ' '.join([word for word in data['text'] if word.strip() != ''])

#     return {'Page Number': page_number, 'Extracted Text': extracted_text}

# # Define the path to the PDF file
# pdf_file = '/content/নারদ ভক্তি সূত্রঃ.pdf'

# # Convert PDF to a list of images with lower DPI
# images = convert_from_path(pdf_file, dpi=100)

# # Determine the pages to process (e.g., process all pages)
# pages_to_process = range(1, len(images) + 1)

# # Create an empty dataframe
# df_test = pd.DataFrame(columns=['Page Number', 'Extracted Text'])

# # Process pages in parallel
# with concurrent.futures.ThreadPoolExecutor() as executor:
#     results = [executor.submit(process_page, i, image) for i, image in enumerate(images, start=1)]

#     # Collect results
#     for future in concurrent.futures.as_completed(results):
#         df_test = df_test.append(future.result(), ignore_index=True)

# # Display the dataframe
# print(df_test)
# # 2.13s
# Out:
#    Page Number                                     Extracted Text
# 0            1  নারদ ভান্ত সূত্র মূল সূত্র, সরল অনুবাদ এবং টীক...
# 1            2  অনুবাদকের নিবেদন পৌরাণিক যুগ থেকেই ভারতীয় মার...
# 2            3  ara Sia অখাতো ভঙ্তিং ব্যাখ্যাস্যামঃ॥ ১॥ অনুবাদ...
# 3            6  8 নারদ ভাক্তসুত্র অনুবাদ। দেবার্ষ নারদ বলেন, “...
# 4            4  ২ নারদ ভক্ত ॥ ৬॥ অনুবাদ। যেটি (পরম প্রেমরুপ ভক...
# 5            5  ৩ নারদ ভাক্তসুত্র ভবতু নিশ্চয়দার্টাদূরধং “TAT...
# 6            7  ৫ নারদ ভাক্তসুত্র ঈশ্বরস্যাপ্যভিমান দেষিত্বাদ ...
# 7            9  a নারদ ভাক্তসুত্র অনুবাদ । (কিন্ত) মহাপুরুষদের...
# 8           10  ৮ নারদ ভক্তিসূত্র _অনুবাদ। কে মায়াকে আতিক্রম ...
# 9            8  ৬ নারদ oie তস্মাৎসৈৰ গ্রাহ্যা মুমুক্ষভিঃ॥ ৩৩। ...
# 10          11  ৯ নারদ ভাক্তসুত্র অনুবাদ । (এরুপ) ভগবদ্প্রেমের...
# 11          13  ১১ নারদ ভাক্তসুত্র স্বীধননাস্তিকবৈরিচরিত্র্ত ন...
# 12          12  30 নারদ ভঙ্তিসূত্র অনুবাদ । উত্তর-উত্তর ক্রমে ...
# 13          14  ১ নারদ ভঙ্তিসত্র অনুবাদ। যখন (এই একান্ত ভক্তদে...
# 14          15  ১৩ নারদ ভাক্তিসুত্র বাহুল্যাবকাশাদনিয়তত্বাচ্চ...
# 15          16  38 aH SR ত্রিসত্যস্য ভক্তিরেব গরীয়সী, ভক্তিরে...

# %%
# import pytesseract
# import pandas as pd
# from pdf2image import convert_from_path
# from PIL import Image
# import io
# import concurrent.futures

# def process_page(page_number, image):
#     img_byte_array = io.BytesIO()
#     image.save(img_byte_array, format='PNG')
#     img_byte_array = img_byte_array.getvalue()

#     # Use Tesseract OCR to get word-level information
#     data = pytesseract.image_to_data(Image.open(io.BytesIO(img_byte_array)), lang='eng+ben', output_type=pytesseract.Output.DICT)

#     # Extract text from non-empty word blocks
#     extracted_text = ' '.join([word for word in data['text'] if word.strip() != ''])

#     return {'Page Number': page_number, 'Extracted Text': extracted_text}

# # Define the path to the PDF file
# pdf_file = '/content/নারদ ভক্তি সূত্রঃ.pdf'

# # Convert PDF to a list of images with lower DPI
# images = convert_from_path(pdf_file, dpi=100)

# # Determine the pages to process (e.g., process all pages)
# pages_to_process = range(1, len(images) + 1)

# # Create an empty dataframe
# df_test = pd.DataFrame(columns=['Page Number', 'Extracted Text'])

# # Adjust the number of concurrent features (increase or decrease based on your system's capacity)
# max_concurrent_features = 100

# # Process pages in parallel with more concurrent features
# with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_features) as executor:
#     results = [executor.submit(process_page, i, image) for i, image in enumerate(images, start=1)]

#     # Collect results
#     for future in concurrent.futures.as_completed(results):
#         df_test = df_test.append(future.result(), ignore_index=True)

# # Display the dataframe
# print(df_test)
# Out:
#    Page Number                                     Extracted Text
# 0            1  নারদ ভান্ত সূত্র মূল সূত্র, সরল অনুবাদ এবং টীক...
# 1            3  ara Sia অখাতো ভঙ্তিং ব্যাখ্যাস্যামঃ॥ ১॥ অনুবাদ...
# 2            6  8 নারদ ভাক্তসুত্র অনুবাদ। দেবার্ষ নারদ বলেন, “...
# 3            2  অনুবাদকের নিবেদন পৌরাণিক যুগ থেকেই ভারতীয় মার...
# 4            7  ৫ নারদ ভাক্তসুত্র ঈশ্বরস্যাপ্যভিমান দেষিত্বাদ ...
# 5           14  ১ নারদ ভঙ্তিসত্র অনুবাদ। যখন (এই একান্ত ভক্তদে...
# 6            5  ৩ নারদ ভাক্তসুত্র ভবতু নিশ্চয়দার্টাদূরধং “TAT...
# 7           15  ১৩ নারদ ভাক্তিসুত্র বাহুল্যাবকাশাদনিয়তত্বাচ্চ...
# 8           10  ৮ নারদ ভক্তিসূত্র _অনুবাদ। কে মায়াকে আতিক্রম ...
# 9            9  a নারদ ভাক্তসুত্র অনুবাদ । (কিন্ত) মহাপুরুষদের...
# 10          13  ১১ নারদ ভাক্তসুত্র স্বীধননাস্তিকবৈরিচরিত্র্ত ন...
# 11          11  ৯ নারদ ভাক্তসুত্র অনুবাদ । (এরুপ) ভগবদ্প্রেমের...
# 12           4  ২ নারদ ভক্ত ॥ ৬॥ অনুবাদ। যেটি (পরম প্রেমরুপ ভক...
# 13          12  30 নারদ ভঙ্তিসূত্র অনুবাদ । উত্তর-উত্তর ক্রমে ...
# 14           8  ৬ নারদ oie তস্মাৎসৈৰ গ্রাহ্যা মুমুক্ষভিঃ॥ ৩৩। ...
# 15          16  38 aH SR ত্রিসত্যস্য ভক্তিরেব গরীয়সী, ভক্তিরে...

# %% [markdown]
# # If you want to make a zip file

# %%
import shutil

# Define the folder path
folder_path = '/content/Text'

# Define the zip file name (without extension)
zip_file_name = '/content/text'

# Create a zip file containing the folder
shutil.make_archive('text', 'zip', '/content/Text')

# # Download the zip file
# from google.colab import files
# files.download(zip_file_name + '.zip')

# %%
# df_test.to_csv('অ্যারিস্টটল এর পলিটিকস By সরদার ফজলুল করীম.csv', index=False)

# %%
df_test

# %% [markdown]
# # import dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASETS/Religious Dictionary.csv")
df_test=pd.read_csv('/content/drive/MyDrive/DATASETS/test/হিন্দুধর্ম্মের নবজাগরণ – স্বামী বিবেকানন্দ.csv')
df_political=pd.read_csv("/content/drive/MyDrive/DATASETS/Political Dictionary .csv")
df_abusive=pd.read_csv("/content/drive/MyDrive/DATASETS/Abuse Dictionary.csv")

# %%
display(df)
display(df_political)
display(df_abusive)
display(df_test)
# Out:
#       page no   Category       Keyword  Examples   label
# 0         NaN  Religious       অংশুমান        NaN    0.0
# 1         NaN  Religious     অক্ষৌহিণী        NaN    0.0
# 2         NaN  Religious         অগ্নি        NaN    0.0
# 3         NaN  Religious       হাঁসিয়া        NaN    0.0
# 4         NaN  Religious         অঙ্গদ        NaN    0.0
# ...       ...        ...           ...        ...    ...
# 1748      NaN        NaN     অসীম দয়া        NaN    NaN
# 1749      NaN        NaN        মুক্তি        NaN    NaN
# 1750      NaN        NaN  শ্রদ্ধাশীলতা        NaN    NaN
# 1751      NaN        NaN        সমর্পণ        NaN    NaN
# 1752      NaN        NaN    পূর্বাচারণ        NaN    NaN
#
# [1753 rows x 5 columns]
#     page   Category              Keyword  Example   Label
# 0    NaN  Political             অকালি দল       NaN      1
# 1    NaN  Political               অছিবাদ       NaN      1
# 2    NaN  Political               অধিকার       NaN      1
# 3    NaN  Political              অধিকারী       NaN      1
# 4    NaN  Political              গঙ্গাধর       NaN      1
# ..   ...        ...                  ...       ...    ...
# 493  NaN  Political           স্তালিনবাদ       NaN      1
# 494  NaN  Political              স্তালিন       NaN      1
# 495  NaN  Political  নিম্নবর্গের রাজনীতি       NaN      1
# 496  NaN  Political         স্বদেশী সমাজ       NaN      1
# 497  NaN  Political          উদৃতত মূল্য       NaN      1
#
# [498 rows x 5 columns]
#      Pageno. Category              Keyword  \
# 0        NaN  Abusive            অঁড়কঁক
# 1        NaN  Abusive         অউরর পোয়া
# 2        NaN  Abusive             অক্কুম
# 3        NaN  Abusive           অকর্মণ্য
# 4        NaN  Abusive             অকর্মা
# ...      ...      ...                  ...
# 3611     NaN  Abusive     শালার ব্যাটা
# 3612     NaN  Abusive          শালি/শালী
# 3613     NaN  Abusive    শালির ছাওয়াল
# 3614     NaN  Abusive  শালির বেটি শালি
# 3615     274  Abusive       শিয়ানতামি
#
#                                                Examples  Label
# 0      শালা আমাকে অঁড়কঁক ভেব্যেচে মাগি | [টানা, স. ব.]    2.0
# 1                দূর অউরর পোয়া, বাজে হথা ন হইস। [চট্ট]    2.0
# 2     চাই থাক, জউরাই গইন্লে ভিডাত্‌ অক্কুম চরাইয়ুম।...    2.0
# 3     তোমার মত অকর্মণ্যের   য়ে করা উচিত হয়নি। [কু]...    2.0
# 4     শালা তুই ত একটা অকর্মা, তোক্‌ দিয়ে কোন কাজ হয...    2.0
# ...                                                 ...    ...
# 3611                    ভাগ শালার ব্যাটাতোর নিকুচি করি।    NaN
# 3612                                এই শালির গরের শালি।    NaN
# 3613                              শালির ছাওয়াল চুপ কর।    NaN
# 3614  রা-শালির বেটি শালির নাংয়ের বাড়ি যাওয়া ভুলিয...    NaN
# 3615                       অত বরো শিয়ানতামি করলো এ্যা।    NaN
#
# [3616 rows x 5 columns]
#                                        Extracted Text
# 0   হিন্দুধন্ের ক্রমাভিব্যক্তি\n\nএক মুহুর্তের মধ্...
# 1   হিন্দুধর্ম্মের নবজাগরণ\n\nভুলিয়া গিয়াছে, মিশ...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূলার\n\n“ব্রহ্মবাদিন্...
# 3   হিন্দুধর্মের নবজাগরণ\n\nঅটল অচল গাত্রে আঘাত কর...
# 4   হিন্দুধর্মের ক্রমাভিব্যক্তি\n\nবংশসমূহ হইতে, ব...
# ..                                                ...
# 86  হিন্দুধন্মের নবজাগরণ\n\nতাহাদের eer জন্য কত লক...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূলার\n\nম্যাক্সমূলার এ...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূলার\n\nমহৎ কার্ষ্যের...
# 89  হিন্দুধর্মের সার্ববভৌমিকতা\n\nহিন্দুধর্মের প্র...
# 90  i~\nহিন্দুধর্মের সার্ববভৌমিকতা\n\nবস্তুস্বন্ধী...
#
# [91 rows x 1 columns]

# %% [markdown]
# # show categories

# %%
#print("categories of Trainset:")
#print(df["category"].unique())
#category_list=df["category"].unique()

# %% [markdown]
# # Preprocessing/Cleaning
# Though the dataset is said to have been cleaned,but i have applied it anyway to remove Unecessary charachters,Emojis,Punctuations with the help of Regex.

# %%
def text_to_word_list(text):
    text = text.split()
    return text

def replace_strings(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           u"\u00C0-\u017F"          #latin
                           u"\u2000-\u206F"          #generalPunctuations

                           "]+", flags=re.UNICODE)
    english_pattern=re.compile('[a-zA-Z0-9]+', flags=re.I)
    #latin_pattern=re.compile('[A-Za-z\u00C0-\u00D6\u00D8-\u00f6\u00f8-\u00ff\s]*',)

    text=emoji_pattern.sub(r'', text)
    text=english_pattern.sub(r'', text)

    return text

def remove_punctuations(my_str):
    # define punctuation
    punctuations = '''````£|¢|Ñ+-*/=EROero৳০১২৩৪৫৬৭৮৯012–34567•89।!()-[]{};:'"“\’,<>./?@#$%^&*_~‘—॥”‰🤣⚽️✌�￰৷￰'''

    no_punct = ""
    for char in my_str:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct



def joining(text):
    out=' '.join(text)
    return out

def preprocessing(text):
    out=remove_punctuations(replace_strings(text))
    return out

# %%
df['cleanText'] = df['Keyword'].apply(lambda x: preprocessing(str(x)))
df_political['cleanText'] = df_political['Keyword'].apply(lambda x: preprocessing(str(x)))
df_abusive['cleanText'] = df_abusive['Keyword'].apply(lambda x: preprocessing(str(x)))
df_test['Extracted Text'] = df_test['Extracted Text'].apply(lambda x: preprocessing(str(x)))

# %% [markdown]
# # Stopwords Removal
# This is a stopwords list containing about 700+ bangla stopwords. I have manually collected this stopwords.

# %%
data1 =pd.read_excel('/content/drive/MyDrive/DATASETS/stopwords_bangla.xlsx')
stop = data1['words'].tolist()

# %%
display(data1)
# Out:
#      Unnamed: 0   words
# 0             0      অই
# 1             1  অগত্যা
# 2             2  অত: পর
# 3             3    অতএব
# 4             4     অথচ
# ..          ...     ...
# 728         728  হয়েছিল
# 729         729   হয়েছে
# 730         730  হয়েছেন
# 731         731     অংশ
# 732         732  অর্থাৎ
#
# [733 rows x 2 columns]

# %%
def stopwordRemoval(text):
    x=str(text)
    l=x.split()

    stm=[elem for elem in l if elem not in stop]

    out=' '.join(stm)

    return str(out)

# %%
df['cleanText'] = df['cleanText'].apply(lambda x: stopwordRemoval(str(x)))
df_political['cleanText'] = df_political['cleanText'].apply(lambda x: stopwordRemoval(str(x)))
df_abusive['cleanText'] = df_abusive['cleanText'].apply(lambda x: stopwordRemoval(str(x)))
df_test['Extracted Text'] = df_test['Extracted Text'].apply(lambda x: stopwordRemoval(str(x)))

# %%
df_test['Extracted Text']
# Out:
# 0     হিন্দুধন্ের ক্রমাভিব্যক্তি মুহুর্তের জগণ্কে শো...
# 1     হিন্দুধর্ম্মের নবজাগরণ ভুলিয়া গিয়াছে মিশনরীগ...
# 2     ভারতবন্ধু অধ্যাপক ম্যক্সমূলার ব্রহ্মবাদিন্ঃ সম...
# 3     হিন্দুধর্মের নবজাগরণ অটল অচল গাত্রে আঘাত করিয়...
# 4     হিন্দুধর্মের ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্...
#                             ...
# 86    হিন্দুধন্মের নবজাগরণ তাহাদের মুদ্রা ব্যয় করিত...
# 87    ভারতবন্ধু অধ্যাপক মাকৃসমূলার ম্যাক্সমূলার একজন...
# 88    ভারতবন্ধু অধ্যাপক ম্যক্সমূলার মহৎ কার্ষ্যের আর...
# 89    হিন্দুধর্মের সার্ববভৌমিকতা হিন্দুধর্মের প্রমাণ...
# 90    হিন্দুধর্মের সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর...
# Name: Extracted Text, Length: 91, dtype: object

# %% [markdown]
# #Stemming

# %%
#make sure to turn on internet on your kernel
#importing stemmer
# !pip install bangla-stemmer
from bangla_stemmer.stemmer import stemmer
## stemmer function
def stem_text (x):
  stmr = stemmer.BanglaStemmer()
  words=x.split(' ')
  stm = stmr.stem(words)
  words=(' ').join(stm)
  return words
# Out:
# Requirement already satisfied: bangla-stemmer in /usr/local/lib/python3.10/dist-packages (1.0)

# %%
df['cleanText']=df['cleanText'].apply(stem_text)
df_political['cleanText']=df_political['cleanText'].apply(stem_text)
df_abusive['cleanText']=df_abusive['cleanText'].apply(stem_text)
df_test['cleanText']=df_test['Extracted Text'].apply(stem_text)
# Out:
# Streaming output truncated to the last 5000 lines.
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# ...
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied second rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied third rules..
# applied first rules..
# applied fourth rules..
# applied first rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied first rules..
# applied fourth rules..
# applied fourth rules..
# applied fourth rules..

# %%
display(df)
display(df_test)
# Out:
#       page no   Category       Keyword  Examples   label     cleanText
# 0         NaN  Religious       অংশুমান        NaN    0.0       অংশুমান
# 1         NaN  Religious     অক্ষৌহিণী        NaN    0.0     অক্ষৌহিণী
# 2         NaN  Religious         অগ্নি        NaN    0.0         অগ্নি
# 3         NaN  Religious       হাঁসিয়া        NaN    0.0       হাঁসিয়া
# 4         NaN  Religious         অঙ্গদ        NaN    0.0         অঙ্গদ
# ...       ...        ...           ...        ...    ...           ...
# 1748      NaN        NaN     অসীম দয়া        NaN    NaN     অসীম দয়া
# 1749      NaN        NaN        মুক্তি        NaN    NaN        মুক্তি
# 1750      NaN        NaN  শ্রদ্ধাশীলতা        NaN    NaN  শ্রদ্ধাশীলতা
# 1751      NaN        NaN        সমর্পণ        NaN    NaN        সমর্পণ
# 1752      NaN        NaN    পূর্বাচারণ        NaN    NaN    পূর্বাচারণ
#
# [1753 rows x 6 columns]
#                                        Extracted Text  \
# 0   হিন্দুধন্ের ক্রমাভিব্যক্তি মুহুর্তের জগণ্কে শো...
# 1   হিন্দুধর্ম্মের নবজাগরণ ভুলিয়া গিয়াছে মিশনরীগ...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূলার ব্রহ্মবাদিন্ঃ সম...
# 3   হিন্দুধর্মের নবজাগরণ অটল অচল গাত্রে আঘাত করিয়...
# 4   হিন্দুধর্মের ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্...
# ..                                                ...
# 86  হিন্দুধন্মের নবজাগরণ তাহাদের মুদ্রা ব্যয় করিত...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূলার ম্যাক্সমূলার একজন...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূলার মহৎ কার্ষ্যের আর...
# 89  হিন্দুধর্মের সার্ববভৌমিকতা হিন্দুধর্মের প্রমাণ...
# 90  হিন্দুধর্মের সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর...
#
#                                             cleanText
# 0   হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত জগণ্ শোৌণিতসা...
# 1   হিন্দুধর্ম্ম নবজাগরণ ভুলিয়া গিয়া মিশনরীগণ অর...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূল ব্রহ্মবাদিন্ঃ সম্প...
# 3   হিন্দুধর্ম নবজাগরণ অটল অচল গাত্রে আঘাত করিয়াছ...
# 4   হিন্দুধর্ম ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্ধধ...
# ..                                                ...
# 86  হিন্দুধন্ম নবজাগরণ তাহা মুদ্ ব্যয় করিতেছেন বা...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূল ম্যাক্সমূল একজন ঘোর...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূল মহৎ কার্ষ্য আরস্ত ...
# 89  হিন্দুধর্ম সার্ববভৌমিকতা হিন্দুধর্ম প্রমাণ্য গ...
# 90  হিন্দুধর্ম সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর্ব...
#
# [91 rows x 2 columns]

# %%
ls
# Out:
# drive/  input.txt  photos/  sample_data/  Text/

# %%
cd content/
# Out:
# [Errno 2] No such file or directory: 'content/'
# /content

# %% [markdown]
# # Showing data frequency

# %%
print("IN TRAIN SET...")
temp1 = df.groupby('Category').count()['cleanText'].reset_index().sort_values(by='cleanText',ascending=False)
temp1.style.background_gradient(cmap='Purples')
# Out:
# IN TRAIN SET...
# <style type="text/css">
# #T_d45d3_row0_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_d45d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d45d3_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_d45d3_level0_col1" class="col_heading level0 col1" >cleanText</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d45d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d45d3_row0_col0" class="data row0 col0" >Religious</td>
#       <td id="T_d45d3_row0_col1" class="data row0 col1" >1389</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("IN TRAIN SET...")
temp2 = df_abusive.groupby('Category').count()['cleanText'].reset_index().sort_values(by='cleanText',ascending=False)
temp2.style.background_gradient(cmap='Purples')
# Out:
# IN TRAIN SET...
# <style type="text/css">
# #T_d638d_row0_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_d638d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d638d_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_d638d_level0_col1" class="col_heading level0 col1" >cleanText</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d638d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d638d_row0_col0" class="data row0 col0" >Abusive</td>
#       <td id="T_d638d_row0_col1" class="data row0 col1" >3588</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("In Test Set...")
temp3 = df_political.groupby('Category').count()['cleanText'].reset_index().sort_values(by='cleanText',ascending=False)
temp3.style.background_gradient(cmap='Purples')
# Out:
# In Test Set...
# <style type="text/css">
# #T_37412_row0_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_37412" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37412_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_37412_level0_col1" class="col_heading level0 col1" >cleanText</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37412_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37412_row0_col0" class="data row0 col0" >Political</td>
#       <td id="T_37412_row0_col1" class="data row0 col1" >498</td>
#     </tr>
#   </tbody>
# </table>

# %%
df
# Out:
#       page no   Category       Keyword  Examples   label     cleanText
# 0         NaN  Religious       অংশুমান        NaN    0.0       অংশুমান
# 1         NaN  Religious     অক্ষৌহিণী        NaN    0.0     অক্ষৌহিণী
# 2         NaN  Religious         অগ্নি        NaN    0.0         অগ্নি
# 3         NaN  Religious       হাঁসিয়া        NaN    0.0       হাঁসিয়া
# 4         NaN  Religious         অঙ্গদ        NaN    0.0         অঙ্গদ
# ...       ...        ...           ...        ...    ...           ...
# 1748      NaN        NaN     অসীম দয়া        NaN    NaN     অসীম দয়া
# 1749      NaN        NaN        মুক্তি        NaN    NaN        মুক্তি
# 1750      NaN        NaN  শ্রদ্ধাশীলতা        NaN    NaN  শ্রদ্ধাশীলতা
# 1751      NaN        NaN        সমর্পণ        NaN    NaN        সমর্পণ
# 1752      NaN        NaN    পূর্বাচারণ        NaN    NaN    পূর্বাচারণ
#
# [1753 rows x 6 columns]

# %% [markdown]
# #  Tokenize the pdf

# %%
# !pip install bnlp_toolkit
# Out:
# Collecting bnlp_toolkit
#   Downloading bnlp_toolkit-4.0.0-py3-none-any.whl (22 kB)
# Collecting sentencepiece (from bnlp_toolkit)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (1.11.3)
# Collecting sklearn-crfsuite (from bnlp_toolkit)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (4.66.1)
# Collecting ftfy (from bnlp_toolkit)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.3 MB/s eta 0:00:00
# Collecting emoji==1.7.0 (from bnlp_toolkit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bnlp_toolkit) (2.31.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->bnlp_toolkit)
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->bnlp_toolkit) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp_toolkit) (2023.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bnlp_toolkit) (2023.7.22)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp_toolkit)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->bnlp_toolkit) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->bnlp_toolkit) (0.9.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171031 sha256=8ddc38515c64203e1778e64248ba86d24cc05da6a7603252243e4b6d6cd49d6f
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: wcwidth, sentencepiece, python-crfsuite, emoji, sklearn-crfsuite, ftfy, bnlp_toolkit
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.10
#     Uninstalling wcwidth-0.2.10:
#       Successfully uninstalled wcwidth-0.2.10
# Successfully installed bnlp_toolkit-4.0.0 emoji-1.7.0 ftfy-6.1.3 python-crfsuite-0.9.9 sentencepiece-0.1.99 sklearn-crfsuite-0.3.6 wcwidth-0.2.12

# %%
 # !git clone https://github.com/sagorbrur/bnlp.git
# Out:
# Cloning into 'bnlp'...
# remote: Enumerating objects: 2048, done.
# remote: Counting objects: 100% (571/571), done.
# remote: Compressing objects: 100% (248/248), done.
# remote: Total 2048 (delta 338), reused 520 (delta 318), pack-reused 1477
# Receiving objects: 100% (2048/2048), 22.74 MiB | 14.37 MiB/s, done.
# Resolving deltas: 100% (1216/1216), done.

# %%
# %cd bnlp
# !python setup.py install
# Out:
# /content/bnlp
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating bnlp_toolkit.egg-info
# writing bnlp_toolkit.egg-info/PKG-INFO
# writing dependency_links to bnlp_toolkit.egg-info/dependency_links.txt
# writing requirements to bnlp_toolkit.egg-info/requires.txt
# writing top-level names to bnlp_toolkit.egg-info/top_level.txt
# writing manifest file 'bnlp_toolkit.egg-info/SOURCES.txt'
# reading manifest file 'bnlp_toolkit.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'bnlp_toolkit.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/bnlp
# copying bnlp/__init__.py -> build/lib/bnlp
# creating build/lib/bnlp/tokenizer
# copying bnlp/tokenizer/__init__.py -> build/lib/bnlp/tokenizer
# copying bnlp/tokenizer/nltk.py -> build/lib/bnlp/tokenizer
# copying bnlp/tokenizer/basic.py -> build/lib/bnlp/tokenizer
# copying bnlp/tokenizer/sentencepiece.py -> build/lib/bnlp/tokenizer
# creating build/lib/bnlp/token_classification
# copying bnlp/token_classification/pos.py -> build/lib/bnlp/token_classification
# copying bnlp/token_classification/__init__.py -> build/lib/bnlp/token_classification
# copying bnlp/token_classification/ner.py -> build/lib/bnlp/token_classification
# copying bnlp/token_classification/token_classification_trainer.py -> build/lib/bnlp/token_classification
# creating build/lib/bnlp/corpus
# copying bnlp/corpus/_stopwords.py -> build/lib/bnlp/corpus
# copying bnlp/corpus/__init__.py -> build/lib/bnlp/corpus
# copying bnlp/corpus/corpus.py -> build/lib/bnlp/corpus
# creating build/lib/bnlp/embedding
# copying bnlp/embedding/__init__.py -> build/lib/bnlp/embedding
# copying bnlp/embedding/fasttext.py -> build/lib/bnlp/embedding
# copying bnlp/embedding/doc2vec.py -> build/lib/bnlp/embedding
# copying bnlp/embedding/glove.py -> build/lib/bnlp/embedding
# copying bnlp/embedding/word2vec.py -> build/lib/bnlp/embedding
# creating build/lib/bnlp/utils
# copying bnlp/utils/__init__.py -> build/lib/bnlp/utils
# copying bnlp/utils/config.py -> build/lib/bnlp/utils
# copying bnlp/utils/utils.py -> build/lib/bnlp/utils
# copying bnlp/utils/downloader.py -> build/lib/bnlp/utils
# creating build/lib/bnlp/cleantext
# copying bnlp/cleantext/__init__.py -> build/lib/bnlp/cleantext
# copying bnlp/cleantext/clean.py -> build/lib/bnlp/cleantext
# copying bnlp/cleantext/constants.py -> build/lib/bnlp/cleantext
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/bnlp
# copying build/lib/bnlp/__init__.py -> build/bdist.linux-x86_64/egg/bnlp
# creating build/bdist.linux-x86_64/egg/bnlp/tokenizer
# copying build/lib/bnlp/tokenizer/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/tokenizer
# copying build/lib/bnlp/tokenizer/nltk.py -> build/bdist.linux-x86_64/egg/bnlp/tokenizer
# copying build/lib/bnlp/tokenizer/basic.py -> build/bdist.linux-x86_64/egg/bnlp/tokenizer
# copying build/lib/bnlp/tokenizer/sentencepiece.py -> build/bdist.linux-x86_64/egg/bnlp/tokenizer
# creating build/bdist.linux-x86_64/egg/bnlp/token_classification
# copying build/lib/bnlp/token_classification/pos.py -> build/bdist.linux-x86_64/egg/bnlp/token_classification
# copying build/lib/bnlp/token_classification/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/token_classification
# copying build/lib/bnlp/token_classification/ner.py -> build/bdist.linux-x86_64/egg/bnlp/token_classification
# copying build/lib/bnlp/token_classification/token_classification_trainer.py -> build/bdist.linux-x86_64/egg/bnlp/token_classification
# creating build/bdist.linux-x86_64/egg/bnlp/corpus
# copying build/lib/bnlp/corpus/_stopwords.py -> build/bdist.linux-x86_64/egg/bnlp/corpus
# copying build/lib/bnlp/corpus/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/corpus
# copying build/lib/bnlp/corpus/corpus.py -> build/bdist.linux-x86_64/egg/bnlp/corpus
# creating build/bdist.linux-x86_64/egg/bnlp/embedding
# copying build/lib/bnlp/embedding/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/embedding
# copying build/lib/bnlp/embedding/fasttext.py -> build/bdist.linux-x86_64/egg/bnlp/embedding
# copying build/lib/bnlp/embedding/doc2vec.py -> build/bdist.linux-x86_64/egg/bnlp/embedding
# copying build/lib/bnlp/embedding/glove.py -> build/bdist.linux-x86_64/egg/bnlp/embedding
# copying build/lib/bnlp/embedding/word2vec.py -> build/bdist.linux-x86_64/egg/bnlp/embedding
# creating build/bdist.linux-x86_64/egg/bnlp/utils
# copying build/lib/bnlp/utils/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/utils
# copying build/lib/bnlp/utils/config.py -> build/bdist.linux-x86_64/egg/bnlp/utils
# copying build/lib/bnlp/utils/utils.py -> build/bdist.linux-x86_64/egg/bnlp/utils
# copying build/lib/bnlp/utils/downloader.py -> build/bdist.linux-x86_64/egg/bnlp/utils
# creating build/bdist.linux-x86_64/egg/bnlp/cleantext
# copying build/lib/bnlp/cleantext/__init__.py -> build/bdist.linux-x86_64/egg/bnlp/cleantext
# copying build/lib/bnlp/cleantext/clean.py -> build/bdist.linux-x86_64/egg/bnlp/cleantext
# copying build/lib/bnlp/cleantext/constants.py -> build/bdist.linux-x86_64/egg/bnlp/cleantext
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/tokenizer/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/tokenizer/nltk.py to nltk.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/tokenizer/basic.py to basic.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/tokenizer/sentencepiece.py to sentencepiece.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/token_classification/pos.py to pos.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/token_classification/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/token_classification/ner.py to ner.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/token_classification/token_classification_trainer.py to token_classification_trainer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/corpus/_stopwords.py to _stopwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/corpus/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/corpus/corpus.py to corpus.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/embedding/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/embedding/fasttext.py to fasttext.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/embedding/doc2vec.py to doc2vec.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/embedding/glove.py to glove.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/embedding/word2vec.py to word2vec.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/utils/config.py to config.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/utils/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/utils/downloader.py to downloader.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/cleantext/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/cleantext/clean.py to clean.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/bnlp/cleantext/constants.py to constants.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying bnlp_toolkit.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying bnlp_toolkit.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying bnlp_toolkit.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying bnlp_toolkit.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying bnlp_toolkit.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/bnlp_toolkit-4.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing bnlp_toolkit-4.0.0-py3.10.egg
# Copying bnlp_toolkit-4.0.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding bnlp-toolkit 4.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/bnlp_toolkit-4.0.0-py3.10.egg
# Processing dependencies for bnlp-toolkit==4.0.0
# Searching for requests==2.31.0
# Best match: requests 2.31.0
# Adding requests 2.31.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for emoji==1.7.0
# Best match: emoji 1.7.0
# Adding emoji 1.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for ftfy==6.1.3
# Best match: ftfy 6.1.3
# Adding ftfy 6.1.3 to easy-install.pth file
# Installing ftfy script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tqdm==4.66.1
# Best match: tqdm 4.66.1
# Adding tqdm 4.66.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sklearn-crfsuite==0.3.6
# Best match: sklearn-crfsuite 0.3.6
# Adding sklearn-crfsuite 0.3.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.11.3
# Best match: scipy 1.11.3
# Adding scipy 1.11.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for nltk==3.8.1
# Best match: nltk 3.8.1
# Adding nltk 3.8.1 to easy-install.pth file
# Installing nltk script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for gensim==4.3.2
# Best match: gensim 4.3.2
# Adding gensim 4.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for sentencepiece==0.1.99
# Best match: sentencepiece 0.1.99
# Adding sentencepiece 0.1.99 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2023.7.22
# Best match: certifi 2023.7.22
# Adding certifi 2023.7.22 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==2.0.7
# Best match: urllib3 2.0.7
# Adding urllib3 2.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wcwidth==0.2.12
# Best match: wcwidth 0.2.12
# Adding wcwidth 0.2.12 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tabulate==0.9.0
# Best match: tabulate 0.9.0
# Adding tabulate 0.9.0 to easy-install.pth file
# Installing tabulate script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-crfsuite==0.9.9
# Best match: python-crfsuite 0.9.9
# Adding python-crfsuite 0.9.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for regex==2023.6.3
# Best match: regex 2023.6.3
# Adding regex 2023.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for joblib==1.3.2
# Best match: joblib 1.3.2
# Adding joblib 1.3.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for click==8.1.7
# Best match: click 8.1.7
# Adding click 8.1.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for smart-open==6.4.0
# Best match: smart-open 6.4.0
# Adding smart-open 6.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for bnlp-toolkit==4.0.0

# %%
from bnlp import NLTKTokenizer
from bnlp import CleanText
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Create an instance of the tokenizer
bnltk = NLTKTokenizer()

# Define a function to tokenize text
def tokenize_text(text):
    return bnltk.word_tokenize(text)

# Apply the tokenization function to the 'Extracted Text' column and create a new column 'Tokenized Text'
df_test['Tokenized Text'] = df_test['cleanText'].apply(tokenize_text)

# Print the DataFrame with tokenized text
print(df_test)
# Out:
#                                        Extracted Text  \
# 0   হিন্দুধন্ের ক্রমাভিব্যক্তি মুহুর্তের জগণ্কে শো...
# 1   হিন্দুধর্ম্মের নবজাগরণ ভুলিয়া গিয়াছে মিশনরীগ...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূলার ব্রহ্মবাদিন্ঃ সম...
# 3   হিন্দুধর্মের নবজাগরণ অটল অচল গাত্রে আঘাত করিয়...
# 4   হিন্দুধর্মের ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্...
# ..                                                ...
# 86  হিন্দুধন্মের নবজাগরণ তাহাদের মুদ্রা ব্যয় করিত...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূলার ম্যাক্সমূলার একজন...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূলার মহৎ কার্ষ্যের আর...
# 89  হিন্দুধর্মের সার্ববভৌমিকতা হিন্দুধর্মের প্রমাণ...
# 90  হিন্দুধর্মের সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর...
#
#                                             cleanText  \
# 0   হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত জগণ্ শোৌণিতসা...
# 1   হিন্দুধর্ম্ম নবজাগরণ ভুলিয়া গিয়া মিশনরীগণ অর...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূল ব্রহ্মবাদিন্ঃ সম্প...
# 3   হিন্দুধর্ম নবজাগরণ অটল অচল গাত্রে আঘাত করিয়াছ...
# 4   হিন্দুধর্ম ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্ধধ...
# ..                                                ...
# 86  হিন্দুধন্ম নবজাগরণ তাহা মুদ্ ব্যয় করিতেছেন বা...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূল ম্যাক্সমূল একজন ঘোর...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূল মহৎ কার্ষ্য আরস্ত ...
# 89  হিন্দুধর্ম সার্ববভৌমিকতা হিন্দুধর্ম প্রমাণ্য গ...
# 90  হিন্দুধর্ম সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর্ব...
#
#                                        Tokenized Text
# 0   [হিন্দুধন্, ক্রমাভিব্যক্তি, মুহুর্ত, জগণ্, শোৌ...
# 1   [হিন্দুধর্ম্ম, নবজাগরণ, ভুলিয়া, গিয়া, মিশনরী...
# 2   [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, ব্রহ্মবাদিন্ঃ,...
# 3   [হিন্দুধর্ম, নবজাগরণ, অটল, অচল, গাত্রে, আঘাত, ...
# 4   [হিন্দুধর্ম, ক্রমাভিব্যক্তি, বংশসমূহ, বিকৃত, ব...
# ..                                                ...
# 86  [হিন্দুধন্ম, নবজাগরণ, তাহা, মুদ্, ব্যয়, করিতে...
# 87  [ভারতবন্ধু, অধ্যাপক, মাকৃসমূল, ম্যাক্সমূল, একজ...
# 88  [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, মহৎ, কার্ষ্য, ...
# 89  [হিন্দুধর্ম, সার্ববভৌমিকতা, হিন্দুধর্ম, প্রমাণ...
# 90  [হিন্দুধর্ম, সার্ববভৌমিকতা, বস্তুস্বন্ধীয়, অপ...
#
# [91 rows x 3 columns]

# %%
df_test
# Out:
#                                        Extracted Text  \
# 0   হিন্দুধন্ের ক্রমাভিব্যক্তি মুহুর্তের জগণ্কে শো...
# 1   হিন্দুধর্ম্মের নবজাগরণ ভুলিয়া গিয়াছে মিশনরীগ...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূলার ব্রহ্মবাদিন্ঃ সম...
# 3   হিন্দুধর্মের নবজাগরণ অটল অচল গাত্রে আঘাত করিয়...
# 4   হিন্দুধর্মের ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্...
# ..                                                ...
# 86  হিন্দুধন্মের নবজাগরণ তাহাদের মুদ্রা ব্যয় করিত...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূলার ম্যাক্সমূলার একজন...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূলার মহৎ কার্ষ্যের আর...
# 89  হিন্দুধর্মের সার্ববভৌমিকতা হিন্দুধর্মের প্রমাণ...
# 90  হিন্দুধর্মের সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর...
#
#                                             cleanText  \
# 0   হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত জগণ্ শোৌণিতসা...
# 1   হিন্দুধর্ম্ম নবজাগরণ ভুলিয়া গিয়া মিশনরীগণ অর...
# 2   ভারতবন্ধু অধ্যাপক ম্যক্সমূল ব্রহ্মবাদিন্ঃ সম্প...
# 3   হিন্দুধর্ম নবজাগরণ অটল অচল গাত্রে আঘাত করিয়াছ...
# 4   হিন্দুধর্ম ক্রমাভিব্যক্তি বংশসমূহ বিকৃত বৌদ্ধধ...
# ..                                                ...
# 86  হিন্দুধন্ম নবজাগরণ তাহা মুদ্ ব্যয় করিতেছেন বা...
# 87  ভারতবন্ধু অধ্যাপক মাকৃসমূল ম্যাক্সমূল একজন ঘোর...
# 88  ভারতবন্ধু অধ্যাপক ম্যক্সমূল মহৎ কার্ষ্য আরস্ত ...
# 89  হিন্দুধর্ম সার্ববভৌমিকতা হিন্দুধর্ম প্রমাণ্য গ...
# 90  হিন্দুধর্ম সার্ববভৌমিকতা বস্তুস্বন্ধীয় অপূর্ব...
#
#                                        Tokenized Text
# 0   [হিন্দুধন্, ক্রমাভিব্যক্তি, মুহুর্ত, জগণ্, শোৌ...
# 1   [হিন্দুধর্ম্ম, নবজাগরণ, ভুলিয়া, গিয়া, মিশনরী...
# 2   [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, ব্রহ্মবাদিন্ঃ,...
# 3   [হিন্দুধর্ম, নবজাগরণ, অটল, অচল, গাত্রে, আঘাত, ...
# 4   [হিন্দুধর্ম, ক্রমাভিব্যক্তি, বংশসমূহ, বিকৃত, ব...
# ..                                                ...
# 86  [হিন্দুধন্ম, নবজাগরণ, তাহা, মুদ্, ব্যয়, করিতে...
# 87  [ভারতবন্ধু, অধ্যাপক, মাকৃসমূল, ম্যাক্সমূল, একজ...
# 88  [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, মহৎ, কার্ষ্য, ...
# 89  [হিন্দুধর্ম, সার্ববভৌমিকতা, হিন্দুধর্ম, প্রমাণ...
# 90  [হিন্দুধর্ম, সার্ববভৌমিকতা, বস্তুস্বন্ধীয়, অপ...
#
# [91 rows x 3 columns]

# %% [markdown]
# # Applying N gram and search

# %%
y=df_test['Extracted Text'].values
y.shape
# Out:
# (91,)

# %%
def generate_N_grams(text,ngram):
  words=[word for word in text.split(" ")]
 # print("Sentence after removing stopwords:",words)
  temp=zip(*[words[i:] for i in range(0,ngram)])
  ans=[' '.join(ngram) for ngram in temp]
  return ans

# %% [markdown]
# # unigram

# %%
unigram=df_test['cleanText'].apply(lambda x: generate_N_grams(x, ngram=1))
print(unigram)
unigram_test=pd.DataFrame(unigram)
print(unigram_test)

# Explode the tokenized text into individual rows
df_test_exploded = unigram_test['cleanText'].explode().reset_index(drop=True)

# Create a new DataFrame with the 'keyword' column
df_test2 = pd.DataFrame({'keyword': df_test_exploded})

# Display the resulting DataFrame
total_word_in_input= len(df_test2)
print(df_test2)

df_test2.value_counts()

word_counts = df_test2.value_counts()
print(word_counts)

search_keys = list(df["Keyword"].dropna())
search_keys_political=list(df_political["Keyword"].dropna())
search_keys_abusive=list(df_abusive["Keyword"].dropna())
total_count_religious=0
total_count_political=0
total_count_abusive=0
print(search_keys)
print(search_keys_political)
print(search_keys_abusive)
found_keys_religious = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keys:
    found_keys_religious[word[0]] = count


found_keys_political = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keys_political:
    found_keys_political[word[0]] = count

found_keys_abusive = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keys_abusive:
    found_keys_abusive[word[0]] = count

print(found_keys_religious)
print(found_keys_political)
print(found_keys_abusive)

total_count_religious = total_count_religious+sum(found_keys_religious.values())
total_count_political = total_count_political+sum(found_keys_political.values())
total_count_abusive= total_count_abusive+sum(found_keys_abusive.values())
print(total_count_religious)
print(total_count_political)
print(total_count_abusive)
print(total_word_in_input)
# Out:
# 0     [হিন্দুধন্, ক্রমাভিব্যক্তি, মুহুর্ত, জগণ্, শোৌ...
# 1     [হিন্দুধর্ম্ম, নবজাগরণ, ভুলিয়া, গিয়া, মিশনরী...
# 2     [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, ব্রহ্মবাদিন্ঃ,...
# 3     [হিন্দুধর্ম, নবজাগরণ, অটল, অচল, গাত্রে, আঘাত, ...
# 4     [হিন্দুধর্ম, ক্রমাভিব্যক্তি, বংশসমূহ, বিকৃত, ব...
#                             ...
# 86    [হিন্দুধন্ম, নবজাগরণ, তাহা, মুদ্, ব্যয়, করিতে...
# 87    [ভারতবন্ধু, অধ্যাপক, মাকৃসমূল, ম্যাক্সমূল, একজ...
# 88    [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, মহৎ, কার্ষ্য, ...
# 89    [হিন্দুধর্ম, সার্ববভৌমিকতা, হিন্দুধর্ম, প্রমাণ...
# 90    [হিন্দুধর্ম, সার্ববভৌমিকতা, বস্তুস্বন্ধীয়, অপ...
# Name: cleanText, Length: 91, dtype: object
#                                             cleanText
# 0   [হিন্দুধন্, ক্রমাভিব্যক্তি, মুহুর্ত, জগণ্, শোৌ...
# 1   [হিন্দুধর্ম্ম, নবজাগরণ, ভুলিয়া, গিয়া, মিশনরী...
# 2   [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, ব্রহ্মবাদিন্ঃ,...
# 3   [হিন্দুধর্ম, নবজাগরণ, অটল, অচল, গাত্রে, আঘাত, ...
# 4   [হিন্দুধর্ম, ক্রমাভিব্যক্তি, বংশসমূহ, বিকৃত, ব...
# ..                                                ...
# 86  [হিন্দুধন্ম, নবজাগরণ, তাহা, মুদ্, ব্যয়, করিতে...
# 87  [ভারতবন্ধু, অধ্যাপক, মাকৃসমূল, ম্যাক্সমূল, একজ...
# 88  [ভারতবন্ধু, অধ্যাপক, ম্যক্সমূল, মহৎ, কার্ষ্য, ...
# 89  [হিন্দুধর্ম, সার্ববভৌমিকতা, হিন্দুধর্ম, প্রমাণ...
# 90  [হিন্দুধর্ম, সার্ববভৌমিকতা, বস্তুস্বন্ধীয়, অপ...
#
# [91 rows x 1 columns]
#              keyword
# 0          হিন্দুধন্
# 1     ক্রমাভিব্যক্তি
# 2            মুহুর্ত
# 3               জগণ্
# 4        শোৌণিতসাগরে
# ...              ...
# 8294             উহা
# 8295         নির্মিত
# 8296            তাহা
# 8297          সমবায়
# 8298         সম্বন্ধ
#
# [8299 rows x 1 columns]
# keyword
# তাহা          105
# না            100
# হইয়া          69
# যাহা           58
# হিন্দুধর্ম     47
#              ...
# পাঁরলোৌকিক      1
# পাঁরিয়         1
# একদেশী          1
# একথা            1
# পানঅর্থ         1
# Length: 4069, dtype: int64
# ['অংশুমান', 'অক্ষৌহিণী', 'অগ্নি', 'হাঁসিয়া', 'অঙ্গদ', 'অঙ্গিরা', 'অগস্ত্য যাত্রা', 'অচিন্ত্য-ভেদ-অভেদ', 'অজ ', 'অজাচার', 'অজন্তা', 'অজমুখ', 'অতীশ দীপঙ্কর, শ্রীজ্ঞান', 'অতিপ্রাকৃত,অতীন্দ্রিয় বা অলৌকিক', 'অজ্ঞেয়বাদ', 'অজিত কেশকম্বলী', 
,4\nপাইয়া,4\nতন্ত্র,4\nনৃতন,4\nউদ্বোধন,4\nপ্রামাণ্য,4\nন,4\nকরিয়,4\nনষ্ট,4\nনহ,4\nপ্রবেশ,4\nনিঃস্বার্থ,4\nপ্রধান,4\nপ্রথমোক্ত,4\nকথিত,4\nকঠোর,4\nন্যায়,4\nতেমনি,4\nপ্রতিষ্ঠিত,4\nপ্রতিধ্বনি,4\nপতিত,4\nপ্রকাশিত,4\nপূর্বেব,4\nপরিচয়,4\nপূর্বব,4\nপুস্তক,4\nএক্ষণে,4\nপুজা,4\nএকমত,4\nএকখানি,4\nধ্বংস,4\nকরুক,4\nবঙ্গদেশ,4\nবঙ্গীয়,4\nতোমাদিগকে,4\nদণ্ডায়মান,4\nকাহা,4\nইতিহাস,4\nবিবেকানন্দ,4\nবিনিময়ে,4\nদিব,4\nকারণে,4\nবাহির,4\nদুরে,4\nদৃষ্,4\nকাধ্য,4\nবাধা,4\nউচ্চারিত,4\nদেবতা,4\nবলিলে,4\nদেশের,4\nদোষ,4\nদ্ব,4\nধারণ,4\nকর্তৃক,4\nবলিতেছি,4\nবর্ষ,4\nবন্ধন,4\nধীহা,4\nআনন্দ,4\n,4\nরামানুজ,4\nরক্ষা,4\nহইলেও,4\nহইয়,4\nআজকাল,4\nশাস্ত্র,4\nমহাত্মা,4\nমেরুদণ্ড,4\nস্থতরাং,4\nযাহ,4\nসংহিতা,4\nঅস্তিত্ব,4\nসাধারণের,4\nসহায়তা,4\nমুক্তির,4\nসহানুভূতির,4\nয়,4\nসহকারে,4\nঅনুভব,4\nম্যায়,4\nসর্বশ্রেষ্ঠ,4\nসমক্ষে,4\nসমর্থ,4\nআকর্ষণ,4\nসম্মুখে,4\nঅঙ্কিত,4\nসমালোচনা,4\nলইয়াই,4\nভোগ,4\nঅকপট,4\nশঙ্কর,4\nরূপ,4\nমধ্য,4\nরহিল,4\nহৃদয়ে,4\nঃ,4\nহিন্দুধশ্ম,4\nলিখিত,4\nপণ্ডিতগণ,3\nপ্রস্তুত,3\nঅপূর্ব,3\nসঞ্চিত,3\nঅপরিচিত,3\nঅপরাপর,3\nসত্য,3\nপদতলে,3\nউন্নত,3\nলক্ষিত,3\nঅরণ্য,3\nউপযুক্ত,3\nলক্ষণ,3\nপ্রার্থনা,3\n ...

# %% [markdown]
# # saving the tokenized words as a data dictonary

# %%
# # Assuming df_test is your original DataFrame
# # Create a new DataFrame df_test2
# df_test2 = pd.DataFrame()

# # Extract the 'Tokenized Text' column from df_test
# tokenized_column = df_test['Tokenized Text']

# # Create a new column 'keyword' in df_test2 and store the tokenized words
# df_test2['keyword'] = tokenized_column.apply(lambda tokens: ', '.join(tokens))

# # Display the resulting DataFrame df_test2
# print(df_test2)

# # Save df_test2 to a CSV file or any other desired format
# df_test2.to_csv('df_test2.csv', index=False)

# %%
 cd ../
# Out:
# /content

# %%
ls
# Out:
# bnlp/  drive/  input.txt  photos/  sample_data/  Text/

# %% [markdown]
# # now for bigram match

# %%
bigram=df_test['cleanText'].apply(lambda x: generate_N_grams(x, ngram=2))
print(bigram)
bigram_test=pd.DataFrame(bigram)
print(bigram_test)

# Explode the tokenized text into individual rows
df_test_explodedB = bigram_test['cleanText'].explode().reset_index(drop=True)

# Create a new DataFrame with the 'keyword' column
df_test2B = pd.DataFrame({'keyword': df_test_explodedB})

# Display the resulting DataFrame
print(df_test2B)

df_test2B.value_counts()

word_counts = df_test2B.value_counts()

print(word_counts)

search_keysB = list(df["Keyword"].dropna())
search_keysB_political=list(df_political["Keyword"].dropna())
search_keysB_abusive=list(df_abusive["Keyword"].dropna())
print(search_keysB)
print(search_keysB_political)
print(search_keysB_abusive)

found_keysB_religious = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysB:
    found_keysB_religious[word[0]] = count


found_keysB_political = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysB_political:
    found_keysB_political[word[0]] = count

found_keysB_abusive = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysB_abusive:
    found_keysB_abusive[word[0]] = count

print(found_keysB_religious)
print(found_keysB_political)
print(found_keysB_abusive)

total_count_religious = total_count_religious+sum(found_keysB_religious.values())
total_count_political = total_count_political+sum(found_keys_political.values())
total_count_abusive= total_count_abusive+sum(found_keysB_abusive.values())
print(total_count_religious)
print(total_count_political)
print(total_count_abusive)
suma=(sum(found_keysB_religious.values())+sum(found_keysB_political.values())+sum(found_keysB_abusive.values()))
total_word_in_input = total_word_in_input - suma *3 + suma
print(total_word_in_input)
# Out:
# 0     [হিন্দুধন্ ক্রমাভিব্যক্তি, ক্রমাভিব্যক্তি মুহু...
# 1     [হিন্দুধর্ম্ম নবজাগরণ, নবজাগরণ ভুলিয়া, ভুলিয়...
# 2     [ভারতবন্ধু অধ্যাপক, অধ্যাপক ম্যক্সমূল, ম্যক্সম...
# 3     [হিন্দুধর্ম নবজাগরণ, নবজাগরণ অটল, অটল অচল, অচল...
# 4     [হিন্দুধর্ম ক্রমাভিব্যক্তি, ক্রমাভিব্যক্তি বংশ...
#                             ...
# 86    [হিন্দুধন্ম নবজাগরণ, নবজাগরণ তাহা, তাহা মুদ্, ...
# 87    [ভারতবন্ধু অধ্যাপক, অধ্যাপক মাকৃসমূল, মাকৃসমূল...
# 88    [ভারতবন্ধু অধ্যাপক, অধ্যাপক ম্যক্সমূল, ম্যক্সম...
# 89    [হিন্দুধর্ম সার্ববভৌমিকতা, সার্ববভৌমিকতা হিন্দ...
# 90    [হিন্দুধর্ম সার্ববভৌমিকতা, সার্ববভৌমিকতা বস্তু...
# Name: cleanText, Length: 91, dtype: object
#                                             cleanText
# 0   [হিন্দুধন্ ক্রমাভিব্যক্তি, ক্রমাভিব্যক্তি মুহু...
# 1   [হিন্দুধর্ম্ম নবজাগরণ, নবজাগরণ ভুলিয়া, ভুলিয়...
# 2   [ভারতবন্ধু অধ্যাপক, অধ্যাপক ম্যক্সমূল, ম্যক্সম...
# 3   [হিন্দুধর্ম নবজাগরণ, নবজাগরণ অটল, অটল অচল, অচল...
# 4   [হিন্দুধর্ম ক্রমাভিব্যক্তি, ক্রমাভিব্যক্তি বংশ...
# ..                                                ...
# 86  [হিন্দুধন্ম নবজাগরণ, নবজাগরণ তাহা, তাহা মুদ্, ...
# 87  [ভারতবন্ধু অধ্যাপক, অধ্যাপক মাকৃসমূল, মাকৃসমূল...
# 88  [ভারতবন্ধু অধ্যাপক, অধ্যাপক ম্যক্সমূল, ম্যক্সম...
# 89  [হিন্দুধর্ম সার্ববভৌমিকতা, সার্ববভৌমিকতা হিন্দ...
# 90  [হিন্দুধর্ম সার্ববভৌমিকতা, সার্ববভৌমিকতা বস্তু...
#
# [91 rows x 1 columns]
#                        keyword
# 0     হিন্দুধন্ ক্রমাভিব্যক্তি
# 1       ক্রমাভিব্যক্তি মুহুর্ত
# 2                 মুহুর্ত জগণ্
# 3             জগণ্ শোৌণিতসাগরে
# 4          শোৌণিতসাগরে প্লাবিত
# ...                        ...
# 8207               মুত্তিক উহা
# 8208               উহা নির্মিত
# 8209              নির্মিত তাহা
# 8210               তাহা সমবায়
# 8211            সমবায় সম্বন্ধ
#
# [8212 rows x 1 columns]
# keyword
# হিন্দুধর্ম নবজাগরণ          15
# হিন্দুধর্ম সার্ববভৌমিকতা    11
# হিন্দুধন্ম নবজাগরণ           9
# শতাব্দী ধরিয়া               8
# যতদিন না                     8
#                             ..
# তাহা অনুভব                   1
# তাহা অধ্যয়ন                 1
# তাহা অতীত                    1
# তাহা অজেয়                   1
# €ম চিকাগো                    1
# Length: 7916, dtype: int64
# ['অংশুমান', 'অক্ষৌহিণী', 'অগ্নি', 'হাঁসিয়া', 'অঙ্গদ', 'অঙ্গিরা', 'অগস্ত্য যাত্রা', 'অচিন্ত্য-ভেদ-অভেদ', 'অজ ', 'অজাচার', 'অজন্তা', 'অজমুখ', 'অতীশ দীপঙ্কর, শ্রীজ্ঞান', 'অতিপ্রাকৃত,অতীন্দ্রিয় বা অলৌকিক', 'অজ্ঞেয়বাদ', 'অজিত কেশকম্বলী', 'অত্রি', 'অথর্ববেদ', 'অদিতি', 'অদ্ভুত রামায়ণম', 'অদ্বৈতবাদ', 'অদ্বয়বজ্র', 'অধিবাস', 'অধ্যাত্মবিদ্যা', 'অনন্তব্রত', 'অনাগারিক ধর্মপাল', 'অনাগামীন', 'অনার্য ', 'অনিরুদ্ধ', 'অনির্বাণ', 'অনুকূলচন্দ্র ঠাকুর', 'অনুগ্রহমূর্তি', 'অন্ত্যেষ্টিক্রিয়া', 'অন্নকূট', 'অন্নপ্রাশন', 'অবতার', 'অবতার নাচ', 'অবধূত', 'অবলোকিতেশ্বর', 'অবিদ্যা', 'অভয়াকর গুপ্ত', 'অভিধস্ম কোষ', 'অভিনন্দ', 'অভেদানন্দ,স্বামী', 'অমরাবতী', 'অমাবস্যা', 'অমিতাভ', 'অমৃত', 'অম্বপালী', 'অম্বুবাচী', 'অরন্ধন', 'অরবিন্দ ঘোষ', 'অরুন্ধতী', 'অর্কব্রত', 'অর্ঘ্য', 'অ
 'আখাউরা  ', 'আখাম্বা  ', 'আখামূরা  ', 'আখার হোসা  ', 'আগডুম বাগডুম  ', 'আগড় বাগড়  ', 'আগয়ান  ', 'আগর মাগর করা  ', 'আগাচাল্যা  ', 'আগাছা  ', 'আগাডগা  ', 'আগাত্\u200c  ', 'আশুইন্যা  ', 'আগুন  ', 'আগুনখাকি  ', 'আগে নাছরী  ', 'আগে মাত্রী  ', 'আঙুলি  ', 'আঙুল চোষা  ', 'আঙুল ফুলে কলাগাছ  ', 'আঙ্গা  ', 'আচমকা  ', 'আচাতুয়া  ', 'আচামুয়া  ', 'আচুদি  ', 'আছুদ্যা  ', 'আচোদা  ', 'আচ্চাক গা  ', 'আচ্চাক্\u200c  ', 'আছাডা  ', 'আছিদর  ', 'আছুন বাইড়া  ', 'আছুনবান্নী  ', 'আছেলা  ', 'আছোদা  ', 'আছোলা  ', 'আছোলা দেওয়া  ', 'আজব  ', 'আজল  ', 'আজাত  ', 'আজাদী  ', 'আজালা  ', 'আটকপালি/আঠকপালী  ', 'আট্কাল  ', 'আট্কালনী  ', 'আট্কি পাট্কি  ', 'আট্কুইরা  ', 'আট্কুড়নি  ', 'আটকুড়া  ', 'আট্খুরা  ', 'আট্খোরা  ', 'আট্ফাটাং  ', 'আটভাট  ', 'আটাইল্\u200c  ', 'আটাপেষা  ', 'আটিয়া খ্যাচর  ', 'আঠাপানি  ', 'আডাইল্যা  ', 'আডার   সা  ', 'আড়ুয়া  ', 'আড্ডুশ  ', 'আড়ুইয়া ', 'আড়ং ধোলাই  ', 'আড়কাঠা  ', 'আড়গাজা  ', 'আড় ভাঙা  ', 'আড়ি  ', 'আড়ুয়া নাগা  ', 'আগ্য়া  ', 'আত্খুয়া  ', 'আত্যালা  ', 'আতত  ', 'আতাই  ', 'আতাকেলু  ', 'আতাখাওরি  ', 'আতান্যা  ', 'আতাবুতা  ', 'আতাল যাতাল  ', 'আতুর  ', 'আতৈক্যা  ', 'আথাইল্\u200c গারিয়া  ', 'আদত্\u200c  ', 'আদৃনা  ', 'আদৃমগা  ', 'আদম্\u200c চোদম  ', 'আদশি  ', 'আদা  ', 'আদাংশাদাং  ', 'আদাখুলা  ', 'আদাগদা  ', 'আদাম্\u200c  ', 'আদিখুলা  ', 'আদিখ্যেতা  ', 'আদুইয়াবৈর  ', 'আদুরী  ', 'আদেআইল্লা  ', 'আদেইল্লা  ', 'আদেখলা/আদেখলে  ', 'আদেলুকা  ', 'আদেলুলে  ', 'আদেল্হা  ', 'আদ্দুচুদা  ', ' আধাখ্যাচড়া   ', 'আধিআ-সাই  ', 'আধেলা চোদা  ', 'আনকোরা  ', 'আনৃগরা  ', 'আন্জাকৃত  ', 'আন্টেংসি  ', 'আনৃতাবৃড ...
# {}
# {}
# {}
# 293
# 92
# 31
# 8299

# %% [markdown]
# # Similarly for trigram

# %%
trigram=df_test['cleanText'].apply(lambda x: generate_N_grams(x, ngram=3))
print(trigram)
trigram_test=pd.DataFrame(trigram)
print(trigram_test)

# Explode the tokenized text into individual rows
df_test_explodedT = trigram_test['cleanText'].explode().reset_index(drop=True)

# Create a new DataFrame with the 'keyword' column
df_test2T = pd.DataFrame({'keyword': df_test_explodedT})

# Display the resulting DataFrame
print(df_test2T)

df_test2T.value_counts()

word_counts = df_test2T.value_counts()
print(word_counts)

search_keysT = list(df["Keyword"].dropna())
search_keysT_political=list(df_political["Keyword"].dropna())
search_keysT_abusive=list(df_abusive["Keyword"].dropna())
print(search_keysT)
print(search_keysT_political)
print(search_keysT_abusive)

found_keysT_religious = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysT:
    found_keysT_religious[word[0]] = count


found_keysT_political = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysT_political:
    found_keysT_political[word[0]] = count

found_keysT_abusive = {}
for word, count in zip(word_counts.keys(), word_counts.values):
  if word[0] in search_keysT_abusive:
    found_keysT_abusive[word[0]] = count

print(found_keysT_religious)
print(found_keysT_political)
print(found_keysT_abusive)

total_count_religious = total_count_religious+sum(found_keysT_religious.values())
total_count_political = total_count_political+sum(found_keysT_political.values())
total_count_abusive= total_count_abusive+sum(found_keysT_abusive.values())
print(total_count_religious)
print(total_count_political)
print(total_count_abusive)

sumt=(sum(found_keysB_religious.values())+sum(found_keysT_political.values())+sum(found_keysT_abusive.values()))
total_word_in_input = total_word_in_input - sumt *3 + sumt
print(total_word_in_input)
# Out:
# 0     [হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত, ক্রমাভিব্যক...
# 1     [হিন্দুধর্ম্ম নবজাগরণ ভুলিয়া, নবজাগরণ ভুলিয়া...
# 2     [ভারতবন্ধু অধ্যাপক ম্যক্সমূল, অধ্যাপক ম্যক্সমূ...
# 3     [হিন্দুধর্ম নবজাগরণ অটল, নবজাগরণ অটল অচল, অটল ...
# 4     [হিন্দুধর্ম ক্রমাভিব্যক্তি বংশসমূহ, ক্রমাভিব্য...
#                             ...
# 86    [হিন্দুধন্ম নবজাগরণ তাহা, নবজাগরণ তাহা মুদ্, ত...
# 87    [ভারতবন্ধু অধ্যাপক মাকৃসমূল, অধ্যাপক মাকৃসমূল ...
# 88    [ভারতবন্ধু অধ্যাপক ম্যক্সমূল, অধ্যাপক ম্যক্সমূ...
# 89    [হিন্দুধর্ম সার্ববভৌমিকতা হিন্দুধর্ম, সার্ববভৌ...
# 90    [হিন্দুধর্ম সার্ববভৌমিকতা বস্তুস্বন্ধীয়, সার্...
# Name: cleanText, Length: 91, dtype: object
#                                             cleanText
# 0   [হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত, ক্রমাভিব্যক...
# 1   [হিন্দুধর্ম্ম নবজাগরণ ভুলিয়া, নবজাগরণ ভুলিয়া...
# 2   [ভারতবন্ধু অধ্যাপক ম্যক্সমূল, অধ্যাপক ম্যক্সমূ...
# 3   [হিন্দুধর্ম নবজাগরণ অটল, নবজাগরণ অটল অচল, অটল ...
# 4   [হিন্দুধর্ম ক্রমাভিব্যক্তি বংশসমূহ, ক্রমাভিব্য...
# ..                                                ...
# 86  [হিন্দুধন্ম নবজাগরণ তাহা, নবজাগরণ তাহা মুদ্, ত...
# 87  [ভারতবন্ধু অধ্যাপক মাকৃসমূল, অধ্যাপক মাকৃসমূল ...
# 88  [ভারতবন্ধু অধ্যাপক ম্যক্সমূল, অধ্যাপক ম্যক্সমূ...
# 89  [হিন্দুধর্ম সার্ববভৌমিকতা হিন্দুধর্ম, সার্ববভৌ...
# 90  [হিন্দুধর্ম সার্ববভৌমিকতা বস্তুস্বন্ধীয়, সার্...
#
# [91 rows x 1 columns]
#                                keyword
# 0     হিন্দুধন্ ক্রমাভিব্যক্তি মুহুর্ত
# 1          ক্রমাভিব্যক্তি মুহুর্ত জগণ্
# 2             মুহুর্ত জগণ্ শোৌণিতসাগরে
# 3             জগণ্ শোৌণিতসাগরে প্লাবিত
# 4          শোৌণিতসাগরে প্লাবিত প্রশংসা
# ...                                ...
# 8120                   ঘটে মুত্তিক উহা
# 8121               মুত্তিক উহা নির্মিত
# 8122                  উহা নির্মিত তাহা
# 8123               নির্মিত তাহা সমবায়
# 8124               তাহা সমবায় সম্বন্ধ
#
# [8125 rows x 1 columns]
# keyword
# ডাঃ পল ভয়স                    3
# ভারতবন্ধু অধ্যাপক ম্যক্সমূল    3
# ভারত অস্তিত্ব বিলুপ্ত          2
# ভক্ত যাহা ভক্ত                 2
# না যতদিন না                    2
#                               ..
# তাহা উহা সকল                   1
# তাহা উহা নুতন                  1
# তাহা উহা করুক                  1
# তাহা ইহাই বটে                  1
# €ম চিকাগো বন্তৃতা              1
# Length: 8106, dtype: int64
# ['অংশুমান', 'অক্ষৌহিণী', 'অগ্নি', 'হাঁসিয়া', 'অঙ্গদ', 'অঙ্গিরা', 'অগস্ত্য যাত্রা', 'অচিন্ত্য-ভেদ-অভেদ', 'অজ ', 'অজাচার', 'অজন্তা', 'অজমুখ', 'অতীশ দীপঙ্কর, শ্রীজ্ঞান', 'অতিপ্রাকৃত,অতীন্দ্রিয় বা অলৌকিক', 'অজ্ঞেয়বাদ', 'অজিত কেশকম্বলী', 'অত্রি', 'অথর্ববেদ', 'অদিতি', 'অদ্ভুত রামায়ণম', 'অদ্বৈতবাদ', 'অদ্বয়বজ্র', 'অধিবাস', 'অধ্যাত্মবিদ্যা', 'অনন্তব্রত', 'অনাগারিক ধর্মপাল', 'অনাগামীন', 'অনার্য ', 'অনিরুদ্ধ', 'অনির্বাণ', 'অনুকূলচন্দ্র ঠাকুর', 'অনুগ্রহমূর্তি', 'অন্ত্যেষ্টিক্রিয়া', 'অন্নকূট', 'অন্নপ্রাশন', 'অবতার', 'অবতার নাচ', 'অবধূত', 'অবলোকিতেশ্বর', 'অবিদ্যা', 'অভয়াকর গুপ্ত', 'অভিধস্ম কোষ', 'অভিনন্দ', 'অভেদানন্দ,স্বামী', 'অমরাবতী', 'অমাবস্যা', 'অমিতাভ', 'অমৃত', 'অম্বপালী', 'অম্বুবাচী', 'অরন্ধন', 'অরবিন্দ ঘোষ', 'অরুন্ধতী', 'অর্ক
 'আখরা  ', 'আখাইয়া  ', 'আখাউরা  ', 'আখাম্বা  ', 'আখামূরা  ', 'আখার হোসা  ', 'আগডুম বাগডুম  ', 'আগড় বাগড়  ', 'আগয়ান  ', 'আগর মাগর করা  ', 'আগাচাল্যা  ', 'আগাছা  ', 'আগাডগা  ', 'আগাত্\u200c  ', 'আশুইন্যা  ', 'আগুন  ', 'আগুনখাকি  ', 'আগে নাছরী  ', 'আগে মাত্রী  ', 'আঙুলি  ', 'আঙুল চোষা  ', 'আঙুল ফুলে কলাগাছ  ', 'আঙ্গা  ', 'আচমকা  ', 'আচাতুয়া  ', 'আচামুয়া  ', 'আচুদি  ', 'আছুদ্যা  ', 'আচোদা  ', 'আচ্চাক গা  ', 'আচ্চাক্\u200c  ', 'আছাডা  ', 'আছিদর  ', 'আছুন বাইড়া  ', 'আছুনবান্নী  ', 'আছেলা  ', 'আছোদা  ', 'আছোলা  ', 'আছোলা দেওয়া  ', 'আজব  ', 'আজল  ', 'আজাত  ', 'আজাদী  ', 'আজালা  ', 'আটকপালি/আঠকপালী  ', 'আট্কাল  ', 'আট্কালনী  ', 'আট্কি পাট্কি  ', 'আট্কুইরা  ', 'আট্কুড়নি  ', 'আটকুড়া  ', 'আট্খুরা  ', 'আট্খোরা  ', 'আট্ফাটাং  ', 'আটভাট  ', 'আটাইল্\u200c  ', 'আটাপেষা  ', 'আটিয়া খ্যাচর  ', 'আঠাপানি  ', 'আডাইল্যা  ', 'আডার   সা  ', 'আড়ুয়া  ', 'আড্ডুশ  ', 'আড়ুইয়া ', 'আড়ং ধোলাই  ', 'আড়কাঠা  ', 'আড়গাজা  ', 'আড় ভাঙা  ', 'আড়ি  ', 'আড়ুয়া নাগা  ', 'আগ্য়া  ', 'আত্খুয়া  ', 'আত্যালা  ', 'আতত  ', 'আতাই  ', 'আতাকেলু  ', 'আতাখাওরি  ', 'আতান্যা  ', 'আতাবুতা  ', 'আতাল যাতাল  ', 'আতুর  ', 'আতৈক্যা  ', 'আথাইল্\u200c গারিয়া  ', 'আদত্\u200c  ', 'আদৃনা  ', 'আদৃমগা  ', 'আদম্\u200c চোদম  ', 'আদশি  ', 'আদা  ', 'আদাংশাদাং  ', 'আদাখুলা  ', 'আদাগদা  ', 'আদাম্\u200c  ', 'আদিখুলা  ', 'আদিখ্যেতা  ', 'আদুইয়াবৈর  ', 'আদুরী  ', 'আদেআইল্লা  ', 'আদেইল্লা  ', 'আদেখলা/আদেখলে  ', 'আদেলুকা  ', 'আদেলুলে  ', 'আদেল্হা  ', 'আদ্দুচুদা  ', ' আধাখ্যাচড়া   ', 'আধিআ-সাই  ', 'আধেলা চোদা  ', 'আনকোরা  ', 'আনৃগরা  ', 'আন্জাকৃত  ', 'আন্টেংসি  ', 'আনৃতাবৃড ...
# {}
# {}
# {}
# 293
# 92
# 31
# 8299

# %%
# Importing wordcloud for plotting word clouds and textwrap for wrapping longer text
from wordcloud import WordCloud
from textwrap import wrap

import matplotlib.pyplot as plt
from matplotlib import font_manager

# Function for generating word clouds
def generate_wordcloud(data,title):
  data = [tuple(x) for x in data.values]
  wc = WordCloud(font_path="/kaggle/input/siyam-rupali-text/Siyamrupali.ttf",width=1080, height=720, max_words=150,colormap="Dark2").generate_from_frequencies(dict(data))
  plt.figure(figsize=(10,8))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis("off")
  plt.title('\n'.join(wrap("Word Cloud of "+title,60)),fontsize=13)
  plt.show()

# %% [markdown]
# # Showing stat for each category

# %%
total_word_in_input
# Out:
# 8299

# %%
religious_key = total_count_religious / total_word_in_input
political_key = total_count_political / total_word_in_input
abusive_key = total_count_abusive / total_word_in_input
print(religious_key )
print(political_key)
print(abusive_key)
# Out:
# 0.035305458488974574
# 0.011085672972647308
# 0.003735389806000723

# %% [markdown]
# # Word Cloud

# %%
category_list=df_test2["keyword"]

# %%
# Function for generating word clouds
def generate_wordcloud(data, title):
    data = [tuple(x) for x in data.values]
    wc = WordCloud(font_path="/content/drive/MyDrive/DATASETS/Siyamrupali.ttf", width=360, height=240, max_words=50, colormap="Dark2").generate_from_frequencies(dict(data))
    plt.figure(figsize=(10, 8))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title('\n'.join(wrap("Word Cloud of " + title, 60)), fontsize=13)
    plt.show()



# Loop through categories and generate word clouds
for i in category_list:
    temp=df_test.loc[df_test2['keyword'] == str(i)]
    #display(temp)
    temp['temp_list'] = temp['cleanText'].apply(lambda x:str(x).split())
    top = Counter([item for sublist in temp['temp_list'] for item in sublist])
    temp = pd.DataFrame(top.most_common(50000))
    temp.columns = ['Common_words','count']
    generate_wordcloud(temp,str(i))

# %%
# %%bash
# # https://github.com/pypa/setuptools/issues/1694#issuecomment-466010982
# pip install gdown --no-use-pep517
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !pip install streamlit
# !pip install pyngrok

# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading PyMuPDF-1.23.6-cp310-none-manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 42.6 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.23.6 (from pymupdf)
#   Downloading PyMuPDFb-1.23.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 35.3 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, pymupdf
# Successfully installed PyMuPDFb-1.23.6 pymupdf-1.23.6

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# Import required libraries
import streamlit as st
import os
from PyPDF2 import PdfFileReader
import shutil

# %%
# %%writefile app.py
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)
st.write ("sonjoy")
# Install necessary libraries




# Create a function to get the number of pages in a PDF
def get_pdf_page_count(pdf_path):
    with open(pdf_path, 'rb') as pdf_file:
        pdf_reader = PdfFileReader(pdf_file)
        return pdf_reader.numPages

# Streamlit app
def main():
    st.title("PDF Upload and Display App")

    # Upload PDF file
    pdf_file = st.file_uploader("Upload a PDF file", type=["pdf"])

    if pdf_file:
        # Save uploaded PDF file to '/content/' path
        pdf_path = "/content/uploaded_file.pdf"
        with open(pdf_path, "wb") as f:
            f.write(pdf_file.getvalue())

    st.dataframe(df)


# Run the Streamlit app
if __name__ == "__main__":
    main()
# Out:
# Overwriting app.py

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# !npm install localtunnel
# !streamlit run /content/app.py &>/content/logs.txt &
# !npx localtunnel --port 8501
#35.196.193.95
